# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
# Details about how CatBoost work
# Catboost is the gradient boosting model that
# https://catboost.ai/en/docs/concepts/algorithm-main-stages
from sklearn.metrics import accuracy_score, log_loss, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split,cross_validate,cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
df = catalog.load("train.encoded")
df.head()
# Out:
# [11/01/22 12:16:52] INFO     Loading data from 'train.encoded' (ParquetDataSet)...              ]8;id=90738;file://C:\Users\Sean\AppData\Local\pypoetry\Cache\virtualenvs\kaggle-kedro-3OK2H3mb-py3.10\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=904144;file://C:\Users\Sean\AppData\Local\pypoetry\Cache\virtualenvs\kaggle-kedro-3OK2H3mb-py3.10\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>HomePlanet</th>
#       <th>CryoSleep</th>
#       <th>Destination</th>
#       <th>Age</th>
#       <th>VIP</th>
#       <th>RoomService</th>
#       <th>FoodCourt</th>
#       <th>ShoppingMall</th>
#       <th>Spa</th>
#       <th>VRDeck</th>
#       <th>Transported</th>
#       <th>Alone</th>
#       <th>Deck</th>
#       <th>Room</th>
#       <th>Side</th>
#       <th>Firstname</th>
#       <th>Lastname</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0001_01</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>39.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>True</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1614</td>
#       <td>1432</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0002_01</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>24.0</td>
#       <td>0</td>
#       <td>109.0</td>
#       <td>9.0</td>
#       <td>25.0</td>
#       <td>549.0</td>
#       <td>44.0</td>
#       <td>True</td>
#       <td>True</td>
#       <td>5</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1407</td>
#       <td>2110</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0003_01</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>58.0</td>
#       <td>1</td>
#       <td>43.0</td>
#       <td>3576.0</td>
#       <td>0.0</td>
#       <td>6715.0</td>
#       <td>49.0</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>156</td>
#       <td>1991</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0003_02</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>33.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1283.0</td>
#       <td>371.0</td>
#       <td>3329.0</td>
#       <td>193.0</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2277</td>
#       <td>1991</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0004_01</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>16.0</td>
#       <td>0</td>
#       <td>303.0</td>
#       <td>70.0</td>
#       <td>151.0</td>
#       <td>565.0</td>
#       <td>2.0</td>
#       <td>True</td>
#       <td>True</td>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2643</td>
#       <td>1779</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.dtypes
# Out:
# PassengerId      object
# HomePlanet        int32
# CryoSleep         int32
# Destination       int32
# Age             float64
# VIP               int32
# RoomService     float64
# FoodCourt       float64
# ShoppingMall    float64
# Spa             float64
# VRDeck          float64
# Transported        bool
# Alone              bool
# Deck              int32
# Room              int64
# Side              int32
# Firstname         int32
# Lastname          int32
# dtype: object

# %%
train_df = df.drop(columns=["PassengerId", "Firstname","Lastname", "Transported"])
target_df = df["Transported"]

# %%
train_df.dtypes
# Out:
# HomePlanet        int32
# CryoSleep         int32
# Destination       int32
# Age             float64
# VIP               int32
# RoomService     float64
# FoodCourt       float64
# ShoppingMall    float64
# Spa             float64
# VRDeck          float64
# Alone              bool
# Deck              int32
# Room              int64
# Side              int32
# dtype: object

# %%
clf = RandomForestClassifier()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\Sean\AppData\Local\Temp\ipykernel_3812\2058515170.py:1 in <cell line: 1>                │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ 'C:\\Users\\Sean\\AppData\\Local\\Temp\\ipykernel_3812\\2058515170.py'                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: 'RandomForestClassifier' object is not callable

# %%
X_train,X_test,y_train,y_test = train_test_split(train_df,target_df,test_size=0.3,random_state=5981)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
X_test
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>HomePlanet</th>
#       <th>CryoSleep</th>
#       <th>Destination</th>
#       <th>Age</th>
#       <th>VIP</th>
#       <th>RoomService</th>
#       <th>FoodCourt</th>
#       <th>ShoppingMall</th>
#       <th>Spa</th>
#       <th>VRDeck</th>
#       <th>Alone</th>
#       <th>Deck</th>
#       <th>Room</th>
#       <th>Side</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6065</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>52.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>652.0</td>
#       <td>9.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>True</td>
#       <td>5</td>
#       <td>1328</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5728</th>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>23.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>723.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>True</td>
#       <td>5</td>
#       <td>1154</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2348</th>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>25.0</td>
#       <td>0</td>
#       <td>1734.0</td>
#       <td>1.0</td>
#       <td>189.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>True</td>
#       <td>5</td>
#       <td>488</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5073</th>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>39.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>829.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>True</td>
#       <td>5</td>
#       <td>1036</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3160</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>15.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>True</td>
#       <td>6</td>
#       <td>547</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2488</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>34.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>382.0</td>
#       <td>0.0</td>
#       <td>87.0</td>
#       <td>236.0</td>
#       <td>False</td>
#       <td>6</td>
#       <td>424</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7003</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>25.0</td>
#       <td>0</td>
#       <td>244.0</td>
#       <td>0.0</td>
#       <td>40.0</td>
#       <td>294.0</td>
#       <td>124.0</td>
#       <td>True</td>
#       <td>5</td>
#       <td>1540</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4411</th>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>37.0</td>
#       <td>0</td>
#       <td>1144.0</td>
#       <td>4.0</td>
#       <td>34.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>3</td>
#       <td>155</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7518</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>False</td>
#       <td>2</td>
#       <td>301</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>632</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>18.0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>True</td>
#       <td>6</td>
#       <td>98</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>2608 rows × 14 columns</p>
# </div>

# %%
y_train
# Out:
# 389      True
# 4587    False
# 1383    False
# 4246    False
# 2266    False
#         ...
# 1042     True
# 8453    False
# 5627     True
# 6789     True
# 8322    False
# Name: Transported, Length: 6085, dtype: bool

# %%
print("---------- RandomForest ----------")

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy =","%.2f"%(accuracy_score(y_test, y_pred)*100), "%")
print("Precision =","%.2f"%(precision_score(y_test, y_pred)*100), "%")
print("Recall =","%.2f"%(recall_score(y_test, y_pred)*100), "%")
print("F1-Score =","%.2f"%(f1_score(y_test, y_pred)*100), "%")
# Out:
# ---------- RandomForest ----------
# Accuracy = 81.06 %
# Precision = 78.74 %
# Recall = 85.45 %
# F1-Score = 81.96 %

# %%
logistic = LogisticRegression(max_iter=3000)
print("---------- Logistic ----------")
clf = logistic
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy =","%.2f"%(accuracy_score(y_test, y_pred)*100), "%")
print("Precision =","%.2f"%(precision_score(y_test, y_pred)*100), "%")
print("Recall =","%.2f"%(recall_score(y_test, y_pred)*100), "%")
print("F1-Score =","%.2f"%(f1_score(y_test, y_pred)*100), "%")
# Out:
# ---------- Logistic ----------
# Accuracy = 81.06 %
# Precision = 78.74 %
# Recall = 85.45 %
# F1-Score = 81.96 %

# %%
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,
                     ignore_warnings=True,
                     custom_metric=None,
                     predictions=False,
                     random_state=12,
                     classifiers='all')

models, predictions = clf.fit(X_train , X_test , y_train , y_test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 29/29 [00:15<00:00,  1.90it/s]

# %%
models
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Accuracy</th>
#       <th>Balanced Accuracy</th>
#       <th>ROC AUC</th>
#       <th>F1 Score</th>
#       <th>Time Taken</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LGBMClassifier</th>
#       <td>0.83</td>
#       <td>0.83</td>
#       <td>0.83</td>
#       <td>0.83</td>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>RandomForestClassifier</th>
#       <td>0.82</td>
#       <td>0.82</td>
#       <td>0.82</td>
#       <td>0.82</td>
#       <td>0.77</td>
#     </tr>
#     <tr>
#       <th>AdaBoostClassifier</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>NuSVC</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>2.42</td>
#     </tr>
#     <tr>
#       <th>SVC</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>2.01</td>
#     </tr>
#     <tr>
#       <th>LogisticRegression</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>ExtraTreesClassifier</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.74</td>
#     </tr>
#     <tr>
#       <th>CalibratedClassifierCV</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>1.44</td>
#     </tr>
#     <tr>
#       <th>LinearSVC</th>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.81</td>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>XGBClassifier</th>
#       <td>0.80</td>
#       <td>0.80</td>
#       <td>0.80</td>
#       <td>0.80</td>
#       <td>1.43</td>
#     </tr>
#     <tr>
#       <th>BaggingClassifier</th>
#       <td>0.79</td>
#       <td>0.79</td>
#       <td>0.79</td>
#       <td>0.79</td>
#       <td>0.22</td>
#     </tr>
#     <tr>
#       <th>SGDClassifier</th>
#       <td>0.79</td>
#       <td>0.79</td>
#       <td>0.79</td>
#       <td>0.79</td>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>RidgeClassifier</th>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>LinearDiscriminantAnalysis</th>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.05</td>
#     </tr>
#     <tr>
#       <th>RidgeClassifierCV</th>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>KNeighborsClassifier</th>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.78</td>
#       <td>0.34</td>
#     </tr>
#     <tr>
#       <th>NearestCentroid</th>
#       <td>0.77</td>
#       <td>0.77</td>
#       <td>0.77</td>
#       <td>0.77</td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>BernoulliNB</th>
#       <td>0.77</td>
#       <td>0.77</td>
#       <td>0.77</td>
#       <td>0.77</td>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>DecisionTreeClassifier</th>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.05</td>
#     </tr>
#     <tr>
#       <th>LabelSpreading</th>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>2.59</td>
#     </tr>
#     <tr>
#       <th>LabelPropagation</th>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>1.85</td>
#     </tr>
#     <tr>
#       <th>ExtraTreeClassifier</th>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.75</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>QuadraticDiscriminantAnalysis</th>
#       <td>0.73</td>
#       <td>0.73</td>
#       <td>0.73</td>
#       <td>0.72</td>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>GaussianNB</th>
#       <td>0.72</td>
#       <td>0.72</td>
#       <td>0.72</td>
#       <td>0.70</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Perceptron</th>
#       <td>0.71</td>
#       <td>0.71</td>
#       <td>0.71</td>
#       <td>0.71</td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>PassiveAggressiveClassifier</th>
#       <td>0.58</td>
#       <td>0.58</td>
#       <td>0.58</td>
#       <td>0.57</td>
#       <td>0.06</td>
#     </tr>
#     <tr>
#       <th>DummyClassifier</th>
#       <td>0.50</td>
#       <td>0.50</td>
#       <td>0.50</td>
#       <td>0.34</td>
#       <td>0.02</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
lgbm = LGBMClassifier()
print("---------- Logistic ----------")
clf = lgbm
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy =","%.2f"%(accuracy_score(y_test, y_pred)*100), "%")
print("Precision =","%.2f"%(precision_score(y_test, y_pred)*100), "%")
print("Recall =","%.2f"%(recall_score(y_test, y_pred)*100), "%")
print("F1-Score =","%.2f"%(f1_score(y_test, y_pred)*100), "%")
# Out:
# ---------- Logistic ----------
# Accuracy = 81.40 %
# Precision = 82.24 %
# Recall = 80.43 %
# F1-Score = 81.32 %
